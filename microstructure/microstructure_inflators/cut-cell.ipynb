# %%
import json, sys, copy, os, igl
import numpy as np
import meshio

def is_inside(v, f, p):
    winds = igl.winding_number(v, f, p)
    mask = np.array(np.rint(winds), dtype=int)
    
    return np.array([e % 2 == 1 for e in mask])

def change_file_extension(filename, new_extension):
  base, ext = os.path.splitext(filename)
  return base + "." + new_extension if ext else filename + "." + new_extension

# %%
microstructure_repo_path = "/home/venky/graphics/microstructure_inflators"
input_surface = "/home/venky/graphics/baton_12.stl"
stitch_cells_cli = os.path.join(microstructure_repo_path, "build/isosurface_inflator/cut_cells_cli")
only_cube_cells = False

# %%
E = 0.01
nu = 0.09
cell_size = 6
# out_path = str(E) + "_" + str(cell_size) + ".obj"
out_path = f"{input_surface[:-4]}_{E}_{cell_size}.obj_{only_cube_cells}.obj"
print(out_path)

m = meshio.read(input_surface)
input_surface = change_file_extension(input_surface, 'obj')
m.write(input_surface)
v = m.points.astype(float)
f = m.cells[0].data
bbox = [np.amin(v, axis=0), np.amax(v, axis=0)]

# corner0 = list(map(int, np.ceil(bbox[0] / cell_size)))
corner0 = list(map(int, np.ceil(bbox[0] / cell_size) - 1))
corner1 = list(map(int, np.floor(bbox[1] / cell_size)))

print(corner0, corner1)

def young(i, j, k):
    # return E
    print(k)
    if k == 0:
        return 0.02
    if k == 1:
        return 0.001
    if k == 2:
        return 0.005
    if k == 3:  
        return 0.005
    if k == 4:
        return 0.005
    if k == 5:
        return 0.005
    if k == 6:
        return 0.005
    if k == 7:
        return 0.005
    if k == 8:
        return 0.005
    if k == 9:
        return 0.005
# Out:
# /home/venky/graphics/baton_12_0.01_6.obj_False.obj
# [-8, -2, 0] [-4, 1, 2]

# %%
sys.path.insert(0, '/home/venky/graphics/matopt/tools/material2geometry')
from material2geometry import Material2Geometry

# %%
mat2geo = Material2Geometry(in_path="/home/venky/graphics/matopt/tools/material2geometry/0646_geo_1_coeffs.txt")
# Out:
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]
# Res: [0.038461538461538464, 0.038461538461538464]
# Width: [13, 13]

# %%
patterns = []
entry = {"params": [],
"symmetry": "Cubic",
"pattern": "/home/venky/graphics/microstructure_inflators/data/patterns/3D/reference_wires/pattern0646.wire",
"index": [0,0,0]}

for i in range(corner0[0], 1 + corner1[0]):
    for j in range(corner0[1], 1 + corner1[1]):
        for k in range(corner0[2], 1 + corner1[2]):
            geo_params = mat2geo.evaluate(nu, young(i, j, k))
            entry["params"] = geo_params
            entry["index"] = [i,j,k]
            patterns.append(copy.deepcopy(entry))

with open("data.json", 'w') as f:
    json.dump(patterns, f)
# Out:
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# 2

# %%
os.system(stitch_cells_cli + " -p data.json " +
           (("--surface " + input_surface) if not only_cube_cells else "") + 
           " --gridSize " + str(cell_size) + " -o " + out_path + " -r 50")
# print((stitch_cells_cli + " -p data.json " +
#            (("--surface " + input_surface) if not only_cube_cells else "") + 
#            " --gridSize " + str(cell_size) + " -o " + out_path + " -r 50"))
# Out:
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 1.66667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 3.33333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 5 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 6.66667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 8.33333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 10 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 11.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 13.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 15 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 16.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 18.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 20 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 21.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 23.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 25 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 26.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 28.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 30 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 31.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 33.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 35 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 36.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 38.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 40 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 41.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 43.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 45 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 46.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 48.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 50 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 51.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 53.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 55 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 56.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 58.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 60 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 61.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 63.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 65 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 66.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 68.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 70 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 71.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 73.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 75 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 76.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 78.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 80 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 81.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 83.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 85 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 86.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 88.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 90 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 91.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 93.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 95 %
# Checking printability
# Inflation graph generated
# Saved space 58.5024 %
# Completed 96.6667 %
# Checking printability
# Inflation graph generated
# Saved space 71.2096 %
# Completed 98.3333 %
# Checking printability
# Inflation graph generated
# Saved space 69.2032 %
# Completed 100 %
# 0

# %%
for c in [1, 2, 3, 4, 5, 6, 7, 8]:
    for E in [1e-3, 2e-3, 5e-3, 1e-2]:
        print(f"Processing for c={c} and E={E}")
        print((np.array(mat2geo.evaluate(nu, E)[5:-4]) * c).tolist())
# Out:
# Processing for c=1 and E=0.001
# [0.12500002236530952, 0.08039353577480896, 0.10304258195535204, 0.15000002683837113]
# Processing for c=1 and E=0.002
# [0.12500002321509995, 0.08246950095234824, 0.10661763958398165, 0.15000002785811953]
# Processing for c=1 and E=0.005
# [0.12500002462842463, 0.0886881045353454, 0.11693105096104062, 0.15000002955410885]
# Processing for c=1 and E=0.01
# [0.12500002371577018, 0.09894629144936973, 0.1327853472775627, 0.15000002845892332]
# Processing for c=2 and E=0.001
# [0.25000004473061904, 0.1607870715496179, 0.20608516391070408, 0.30000005367674226]
# Processing for c=2 and E=0.002
# [0.2500000464301999, 0.1649390019046965, 0.2132352791679633, 0.30000005571623906]
# Processing for c=2 and E=0.005
# [0.25000004925684927, 0.1773762090706908, 0.23386210192208123, 0.3000000591082177]
# Processing for c=2 and E=0.01
# [0.25000004743154036, 0.19789258289873946, 0.2655706945551254, 0.30000005691784665]
# Processing for c=3 and E=0.001
# [0.3750000670959286, 0.24118060732442687, 0.3091277458660561, 0.4500000805151134]
# Processing for c=3 and E=0.002
# [0.37500006964529986, 0.24740850285704474, 0.319852918751945, 0.4500000835743586]
# Processing for c=3 and E=0.005
# [0.3750000738852739, 0.2660643136060362, 0.35079315288312185, 0.45000008866232655]
# Processing for c=3 and E=0.01
# [0.37500007114731054, 0.2968388743481092, 0.3983560418326881, 0.45000008537676994]
# Processing for c=4 and E=0.001
# [0.5000000894612381, 0.3215741430992358, 0.41217032782140817, 0.6000001073534845]
# Processing for c=4 and E=0.002
# [0.5000000928603998, 0.329878003809393, 0.4264705583359266, 0.6000001114324781]
# Processing for c=4 and E=0.005
# [0.5000000985136985, 0.3547524181413816, 0.46772420384416247, 0.6000001182164354]
# Processing for c=4 and E=0.01
# [0.5000000948630807, 0.3957851657974789, 0.5311413891102508, 0.6000001138356933]
# Processing for c=5 and E=0.001
# [0.6250001118265476, 0.4019676788740448, 0.5152129097767602, 0.7500001341918556]
# Processing for c=5 and E=0.002
# [0.6250001160754998, 0.4123475047617412, 0.5330881979199082, 0.7500001392905976]
# Processing for c=5 and E=0.005
# [0.6250001231421232, 0.44344052267672696, 0.5846552548052031, 0.7500001477705442]
# Processing for c=5 and E=0.01
# [0.625000118578851, 0.49473145724684864, 0.6639267363878134, 0.7500001422946166]
# Processing for c=6 and E=0.001
# [0.7500001341918572, 0.48236121464885373, 0.6182554917321123, 0.9000001610302268]
# Processing for c=6 and E=0.002
# [0.7500001392905997, 0.4948170057140895, 0.63970583750389, 0.9000001671487172]
# Processing for c=6 and E=0.005
# [0.7500001477705478, 0.5321286272120724, 0.7015863057662437, 0.9000001773246531]
# Processing for c=6 and E=0.01
# [0.7500001422946211, 0.5936777486962184, 0.7967120836653762, 0.9000001707535399]
# Processing for c=7 and E=0.001
# [0.8750001565571667, 0.5627547504236627, 0.7212980736874643, 1.0500001878685978]
# Processing for c=7 and E=0.002
# [0.8750001625056997, 0.5772865066664377, 0.7463234770878716, 1.0500001950068367]
# Processing for c=7 and E=0.005
# [0.8750001723989724, 0.6208167317474178, 0.8185173567272843, 1.050000206878762]
# Processing for c=7 and E=0.01
# [0.8750001660103912, 0.6926240401455881, 0.9294974309429389, 1.0500001992124632]
# Processing for c=8 and E=0.001
# [1.0000001789224762, 0.6431482861984716, 0.8243406556428163, 1.200000214706969]
# Processing for c=8 and E=0.002
# [1.0000001857207996, 0.659756007618786, 0.8529411166718532, 1.2000002228649562]
# Processing for c=8 and E=0.005
# [1.000000197027397, 0.7095048362827632, 0.9354484076883249, 1.2000002364328708]
# Processing for c=8 and E=0.01
# [1.0000001897261614, 0.7915703315949578, 1.0622827782205015, 1.2000002276713866]

# %%
import pandas as pd
import numpy as np

c_values = [1, 2, 3, 4, 5, 6, 7, 8, 16]
E_values = [1e-3, 2e-3, 5e-3, 1e-2, 2e-2]

df = pd.DataFrame(index=c_values, columns=E_values)

df.index.name = "Cell Size (c)"
df.columns.name = "Young's Modulus (E)"

for c in c_values:
    for E in E_values:
        arr = np.array(mat2geo.evaluate(nu, E)[5:-4]) * c
        min_dim = np.min(arr)        
        if min_dim < 0.4:
            df.loc[c, E] = "Unprintable"
        else:
            df.loc[c, E] = f"{min_dim:.4f}"

df
# Out:
# Young's Modulus (E)        0.001        0.002        0.005        0.010  \
# Cell Size (c)
# 1                    Unprintable  Unprintable  Unprintable  Unprintable
# 2                    Unprintable  Unprintable  Unprintable  Unprintable
# 3                    Unprintable  Unprintable  Unprintable  Unprintable
# 4                    Unprintable  Unprintable  Unprintable  Unprintable
# 5                         0.4020       0.4123       0.4434       0.4947
# 6                         0.4824       0.4948       0.5321       0.5937
# 7                         0.5628       0.5773       0.6208       0.6926
# 8                         0.6431       0.6598       0.7095       0.7916
# 16                        1.2863       1.3195       1.4190       1.5831
#
# Young's Modulus (E)        0.020
# Cell Size (c)
# 1                    Unprintable
# 2                    Unprintable
# 3                    Unprintable
# 4                         0.4740
# 5                         0.5925
# 6                         0.7110
# 7                         0.8295
# 8                         0.9480
# 16                        1.8960
